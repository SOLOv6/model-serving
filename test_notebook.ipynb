# %%
import requests
import json
from PIL import Image
import base64
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

# %%
# !pwd
# Out:
# /home/solov6project/SOLOv6/TorchServe

# %%
test_image = '/home/solov6project/SOLOv6/test_image/20180102_5190_10649594_0573eda83d6edd932d62ad69508c64f0_augmented11.jpg'
image = cv2.imread(test_image)
plt.imshow(image)

# %%
type(image)
# Out:
# numpy.ndarray

# %%
with open(test_image, 'rb') as f:
    data = f.read()

# %%
with open(test_image, 'rb') as img:
    base64_string1 = base64.b64encode(img.read())

# %%
data_b = base64_string1.decode()

# %%
# raw = cv2.imread(test_image)
# raw = base64.b64encode(test_image)

data_info = {'data':base64_string1, 'path':'test-image_name'}

# %%
import json

# %%
# data = {}
res = requests.post("http://0.0.0.0:3000/predictions/model", data=data_info)

# %%
res
# Out:
# <Response [200]>

# %%
res.content
# Out:
# b'{\n  "conf": 0.0,\n  "is_damaged": false\n}'

# %%
result = res.content

# %%
result_de = result.decode()

# %%
from io import StringIO
io = StringIO(result_de)
conf = json.load(io)

# %%
conf
# Out:
# {'conf': 0.0, 'is_damaged': False}

# %%
result['conf']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-5f8e4512530c> in <module>
# ----> 1 result['conf']
#
# TypeError: string indices must be integers
